# %%
# !pwd
# Out:
# /c/Users/manu/ScannerTire

# %%
import numpy as np

import matplotlib.pyplot as plt

from scipy import interpolate
from scipy.interpolate import interp1d

# load depth data
depths = np.load('depths.npy')
# convert to list
depths = depths.tolist()


Z = np.array([d[2] for d in depths])


plt.plot(Z)
plt.show()

# %%
# save the interpolated data
interpolated = linfit(np.linspace(1,n*10,n*10))

plt.imshow(interpolated)

# %%
import numpy as np
from stl import mesh
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 from stl import mesh
#
# ModuleNotFoundError: No module named 'stl'

# %%
from PIL import Image, ImageFilter
#load the image
img = Image.open('image.jpg')
# rotate the image
img = img.rotate(90)
#increase the contrast
img = Image.eval(img, lambda x: x*1.2)
# get just the contour of the items in the image
img = img.filter(ImageFilter.CONTOUR)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from PIL import Image, ImageFilter
#       2 #load the image
# ----> 3 img = Image.open('image.jpg')
#       4 # rotate the image
#       5 img = img.rotate(90)
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image.jpg'

# %%
import numpy as np
import matplotlib.pyplot as plt



data = np.load('dz_processed.npy')
# # convert (5, 1296, 1, 2) to (5, 1296, 2)
# data = data.reshape(5, 2304, 2)
# # get the first element of each 1296 elements
# data = data[:, :, 0]
# print(data[0])
# plt.plot(data[0])
# plt.show()

plt.imshow(data)
plt.show()

# %%
from picamera2 import Picamera2

picam = Picamera2()
# Out:
# Camera __init__ sequence did not complete.
# [0:50:18.079320074] [3533] ERROR Camera camera.cpp:685 Camera in Acquired state trying acquire() requiring state Available
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/picamera2/picamera2.py:269, in Picamera2.__init__(self, camera_num, verbose_console, tuning, allocator)
#     268 try:
# --> 269     self._open_camera()
#     270     _log.debug(f"{self.camera_manager}")
#
# File /usr/lib/python3/dist-packages/picamera2/picamera2.py:478, in Picamera2._open_camera(self)
#     477 # This now throws an error if it can't open the camera.
# --> 478 self.camera.acquire()
#     480 self.is_open = True
#
# RuntimeError: Failed to acquire camera: Device or resource busy
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 3
#       1 from picamera2 import Picamera2
# ----> 3 picam = Picamera2()
#
# File /usr/lib/python3/dist-packages/picamera2/picamera2.py:281, in Picamera2.__init__(self, camera_num, verbose_console, tuning, allocator)
#     279 except Exception:
#     280     _log.error("Camera __init__ sequence did not complete.")
# --> 281     raise RuntimeError("Camera __init__ sequence did not complete.")
#     282 finally:
#     283     if tuning_file is not None:
#
# RuntimeError: Camera __init__ sequence did not complete.
